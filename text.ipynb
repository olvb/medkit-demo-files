# %%
#!pip install ./medkit_lib-0.13a0-py3-none-any.whl[all]
# Out:
# Processing ./medkit_lib-0.13a0-py3-none-any.whl
# Requirement already satisfied: Unidecode in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.3.7)
# Requirement already satisfied: duptextfinder in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.2)
# Requirement already satisfied: flashtext<3.0,>=2.7 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (2.7)
# Requirement already satisfied: iamsystem>=0.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.5.1)
# Requirement already satisfied: intervaltree in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (3.1.0)
# Requirement already satisfied: numpy in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.24.4)
# Requirement already satisfied: pyaml in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (23.9.7)
# Requirement already satisfied: requests in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (2.31.0)
# Requirement already satisfied: smart-open in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (6.4.0)
# Requirement already satisfied: soundfile in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.12.1)
# Requirement already satisfied: tqdm in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (4.66.1)
# Requirement already satisfied: typing-extensions in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (4.4.0)
# Requirement already satisfied: wheel in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.41.3)
# Requirement already satisfied: PyRuSH<2.0,>=1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.0.7)
# Requirement already satisfied: edsnlp==0.9.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.9.1)
# Requirement already satisfied: feather-format<0.5,>=0.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.4.1)
# Requirement already satisfied: packaging in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (23.2)
# Requirement already satisfied: pandas<2.0,>=1.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.5.3)
# Requirement already satisfied: pyannote-audio<4.0,>=3.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (3.1.1)
# Requirement already satisfied: pyannote-core<6.0.0,>=5.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (5.0.0)
# Requirement already satisfied: pyannote-metrics<4.0.0,>=3.2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (3.2.1)
# Requirement already satisfied: pysrt<2.0.0,>=1.1.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.1.2)
# Requirement already satisfied: quickumls<2.0,>=1.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.4.2)
# Requirement already satisfied: resampy<0.5,>=0.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.4.2)
# Requirement already satisfied: sacremoses in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.1.1)
# Requirement already satisfied: scikit-learn<2.0.0,>=1.3.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.3.2)
# Requirement already satisfied: sentencepiece in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.1.99)
# Requirement already satisfied: seqeval<2.0.0,>=1.2.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (1.2.2)
# Requirement already satisfied: spacy<4.0,>=3.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (3.7.2)
# Requirement already satisfied: speechbrain<0.6,>=0.5 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.5.15)
# Requirement already satisfied: torch<3.0.0,>=2.1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (2.1.1)
# Requirement already satisfied: torchaudio<3.0.0,>=2.1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (2.1.1)
# Requirement already satisfied: transformers<5.0,>=4.21 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (4.35.2)
# Requirement already satisfied: unqlite<0.10.0,>=0.9.6 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (0.9.6)
# Requirement already satisfied: webrtcvad<3.0,>=2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from medkit-lib==0.13a0) (2.0.10)
# Requirement already satisfied: decorator in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (5.1.1)
# Requirement already satisfied: loguru in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (0.7.2)
# Requirement already satisfied: pendulum>=2.1.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (2.1.2)
# Requirement already satisfied: pydantic<2.0.0,>=1.10.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (1.10.13)
# Requirement already satisfied: pysimstring>=1.2.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (1.2.1)
# Requirement already satisfied: regex in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (2022.3.2)
# Requirement already satisfied: rich>=12.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (13.7.0)
# Requirement already satisfied: thinc>=8.1.10 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (8.2.1)
# Requirement already satisfied: umls-downloader>=0.1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from edsnlp==0.9.1->medkit-lib==0.13a0) (0.1.2)
# Requirement already satisfied: pyarrow>=0.4.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from feather-format<0.5,>=0.4->medkit-lib==0.13a0) (14.0.1)
# Requirement already satisfied: spellwise>=0.8.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from iamsystem>=0.3->medkit-lib==0.13a0) (0.8.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pandas<2.0,>=1.4->medkit-lib==0.13a0) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pandas<2.0,>=1.4->medkit-lib==0.13a0) (2023.3.post1)
# Requirement already satisfied: asteroid-filterbanks>=0.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.4.0)
# Requirement already satisfied: einops>=0.6.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.7.0)
# Requirement already satisfied: huggingface-hub>=0.13.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.19.4)
# Requirement already satisfied: lightning>=2.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (2.1.2)
# Requirement already satisfied: omegaconf<3.0,>=2.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (2.3.0)
# Requirement already satisfied: pyannote.database>=5.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (5.0.1)
# Requirement already satisfied: pyannote.pipeline>=3.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.0.1)
# Requirement already satisfied: pytorch-metric-learning>=2.1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (2.3.0)
# Requirement already satisfied: semver>=3.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.0.2)
# Requirement already satisfied: tensorboardX>=2.6 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (2.6.2.2)
# Requirement already satisfied: torch-audiomentations>=0.11.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.11.0)
# Requirement already satisfied: torchmetrics>=0.11.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.2.0)
# Requirement already satisfied: sortedcontainers>=2.0.4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-core<6.0.0,>=5.0.0->medkit-lib==0.13a0) (2.4.0)
# Requirement already satisfied: scipy>=1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-core<6.0.0,>=5.0.0->medkit-lib==0.13a0) (1.9.3)
# Requirement already satisfied: docopt>=0.6.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (0.6.2)
# Requirement already satisfied: tabulate>=0.7.7 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (0.9.0)
# Requirement already satisfied: matplotlib>=2.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (3.7.4)
# Requirement already satisfied: sympy>=1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (1.12)
# Requirement already satisfied: PyFastNER>=1.0.8 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from PyRuSH<2.0,>=1.0->medkit-lib==0.13a0) (1.0.9)
# Requirement already satisfied: quicksectx>=0.3.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from PyRuSH<2.0,>=1.0->medkit-lib==0.13a0) (0.3.3)
# Requirement already satisfied: chardet in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pysrt<2.0.0,>=1.1.2->medkit-lib==0.13a0) (5.2.0)
# Requirement already satisfied: leveldb>=0.193 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from quickumls<2.0,>=1.4->medkit-lib==0.13a0) (0.201)
# Requirement already satisfied: nltk>=3.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from quickumls<2.0,>=1.4->medkit-lib==0.13a0) (3.8.1)
# Requirement already satisfied: quickumls-simstring>=1.1.5r1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from quickumls<2.0,>=1.4->medkit-lib==0.13a0) (1.1.5.post1)
# Requirement already satisfied: six in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from quickumls<2.0,>=1.4->medkit-lib==0.13a0) (1.16.0)
# Requirement already satisfied: numba>=0.53 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from resampy<0.5,>=0.4->medkit-lib==0.13a0) (0.58.1)
# Requirement already satisfied: joblib>=1.1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.3.2->medkit-lib==0.13a0) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from scikit-learn<2.0.0,>=1.3.2->medkit-lib==0.13a0) (3.2.0)
# Requirement already satisfied: cffi>=1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from soundfile->medkit-lib==0.13a0) (1.16.0)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.11 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (3.0.12)
# Requirement already satisfied: spacy-loggers<2.0.0,>=1.0.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (1.0.5)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (1.0.10)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (2.0.8)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (3.0.9)
# Requirement already satisfied: wasabi<1.2.0,>=0.9.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (1.1.2)
# Requirement already satisfied: srsly<3.0.0,>=2.4.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (2.4.8)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.6 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (2.0.10)
# Requirement already satisfied: weasel<0.4.0,>=0.1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (0.3.4)
# Requirement already satisfied: typer<0.10.0,>=0.3.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (0.9.0)
# Requirement already satisfied: jinja2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (3.1.2)
# Requirement already satisfied: setuptools in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (69.0.0)
# Requirement already satisfied: langcodes<4.0.0,>=3.2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from spacy<4.0,>=3.4->medkit-lib==0.13a0) (3.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from requests->medkit-lib==0.13a0) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from requests->medkit-lib==0.13a0) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from requests->medkit-lib==0.13a0) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from requests->medkit-lib==0.13a0) (2023.11.17)
# Requirement already satisfied: hyperpyyaml in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from speechbrain<0.6,>=0.5->medkit-lib==0.13a0) (1.2.2)
# Requirement already satisfied: filelock in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (3.13.1)
# Requirement already satisfied: networkx in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (3.1)
# Requirement already satisfied: fsspec in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (2023.10.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.1.105 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.1.105 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.105)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.1.105 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.105)
# Requirement already satisfied: nvidia-cudnn-cu12==8.9.2.26 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (8.9.2.26)
# Requirement already satisfied: nvidia-cublas-cu12==12.1.3.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.3.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.0.2.54 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (11.0.2.54)
# Requirement already satisfied: nvidia-curand-cu12==10.3.2.106 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (10.3.2.106)
# Requirement already satisfied: nvidia-cusolver-cu12==11.4.5.107 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (11.4.5.107)
# Requirement already satisfied: nvidia-cusparse-cu12==12.1.0.106 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.0.106)
# Requirement already satisfied: nvidia-nccl-cu12==2.18.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (2.18.1)
# Requirement already satisfied: nvidia-nvtx-cu12==12.1.105 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.1.105)
# Requirement already satisfied: triton==2.1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (2.1.0)
# Requirement already satisfied: nvidia-nvjitlink-cu12 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from nvidia-cusolver-cu12==11.4.5.107->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (12.3.101)
# Requirement already satisfied: pyyaml>=5.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from transformers<5.0,>=4.21->medkit-lib==0.13a0) (6.0.1)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from transformers<5.0,>=4.21->medkit-lib==0.13a0) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from transformers<5.0,>=4.21->medkit-lib==0.13a0) (0.4.0)
# Requirement already satisfied: Cython in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from unqlite<0.10.0,>=0.9.6->medkit-lib==0.13a0) (3.0.5)
# Requirement already satisfied: click in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from sacremoses->medkit-lib==0.13a0) (8.1.7)
# Requirement already satisfied: pycparser in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from cffi>=1.0->soundfile->medkit-lib==0.13a0) (2.21)
# Requirement already satisfied: lightning-utilities<2.0,>=0.8.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from lightning>=2.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.10.0)
# Requirement already satisfied: pytorch-lightning in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from lightning>=2.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (2.1.2)
# Requirement already satisfied: contourpy>=1.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (1.1.1)
# Requirement already satisfied: cycler>=0.10 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (4.45.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (1.4.5)
# Requirement already satisfied: pillow>=6.2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (3.1.1)
# Requirement already satisfied: importlib-resources>=3.2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (6.1.1)
# Requirement already satisfied: llvmlite<0.42,>=0.41.0dev0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from numba>=0.53->resampy<0.5,>=0.4->medkit-lib==0.13a0) (0.41.1)
# Requirement already satisfied: importlib-metadata in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from numba>=0.53->resampy<0.5,>=0.4->medkit-lib==0.13a0) (6.8.0)
# Requirement already satisfied: antlr4-python3-runtime==4.9.* in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from omegaconf<3.0,>=2.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (4.9.3)
# Requirement already satisfied: pytzdata>=2020.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pendulum>=2.1.2->edsnlp==0.9.1->medkit-lib==0.13a0) (2020.1)
# Requirement already satisfied: optuna>=3.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.4.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from rich>=12.0.0->edsnlp==0.9.1->medkit-lib==0.13a0) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from rich>=12.0.0->edsnlp==0.9.1->medkit-lib==0.13a0) (2.17.1)
# Requirement already satisfied: mpmath>=0.19 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from sympy>=1.1->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (1.3.0)
# Requirement already satisfied: protobuf>=3.20 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from tensorboardX>=2.6->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (4.25.1)
# Requirement already satisfied: blis<0.8.0,>=0.7.8 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from thinc>=8.1.10->edsnlp==0.9.1->medkit-lib==0.13a0) (0.7.11)
# Requirement already satisfied: confection<1.0.0,>=0.0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from thinc>=8.1.10->edsnlp==0.9.1->medkit-lib==0.13a0) (0.1.3)
# Requirement already satisfied: julius<0.3,>=0.2.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.2.7)
# Requirement already satisfied: librosa>=0.6.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.10.1)
# Requirement already satisfied: torch-pitch-shift>=1.2.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.2.4)
# Requirement already satisfied: more-click in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from umls-downloader>=0.1.1->edsnlp==0.9.1->medkit-lib==0.13a0) (0.1.2)
# Requirement already satisfied: beautifulsoup4 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from umls-downloader>=0.1.1->edsnlp==0.9.1->medkit-lib==0.13a0) (4.12.2)
# Requirement already satisfied: pystow in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from umls-downloader>=0.1.1->edsnlp==0.9.1->medkit-lib==0.13a0) (0.5.2)
# Requirement already satisfied: cloudpathlib<0.17.0,>=0.7.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from weasel<0.4.0,>=0.1.0->spacy<4.0,>=3.4->medkit-lib==0.13a0) (0.16.0)
# Requirement already satisfied: ruamel.yaml>=0.17.28 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from hyperpyyaml->speechbrain<0.6,>=0.5->medkit-lib==0.13a0) (0.18.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from jinja2->spacy<4.0,>=3.4->medkit-lib==0.13a0) (2.1.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (3.9.0)
# Requirement already satisfied: zipp>=3.1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from importlib-resources>=3.2.0->matplotlib>=2.0.0->pyannote-metrics<4.0.0,>=3.2.0->medkit-lib==0.13a0) (3.17.0)
# Requirement already satisfied: audioread>=2.1.9 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.0.1)
# Requirement already satisfied: pooch>=1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.8.0)
# Requirement already satisfied: soxr>=0.3.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.3.7)
# Requirement already satisfied: lazy-loader>=0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (0.3)
# Requirement already satisfied: msgpack>=1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.0.7)
# Requirement already satisfied: mdurl~=0.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from markdown-it-py>=2.2.0->rich>=12.0.0->edsnlp==0.9.1->medkit-lib==0.13a0) (0.1.2)
# Requirement already satisfied: alembic>=1.5.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.12.1)
# Requirement already satisfied: colorlog in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (6.7.0)
# Requirement already satisfied: sqlalchemy>=1.3.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.4.50)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.7 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from ruamel.yaml>=0.17.28->hyperpyyaml->speechbrain<0.6,>=0.5->medkit-lib==0.13a0) (0.2.8)
# Requirement already satisfied: primePy>=1.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from torch-pitch-shift>=1.2.2->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.3)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0,>=3.4->medkit-lib==0.13a0) (0.4.6)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from typer<0.10.0,>=0.3.0->spacy<4.0,>=3.4->medkit-lib==0.13a0) (1.5.4)
# Requirement already satisfied: soupsieve>1.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from beautifulsoup4->umls-downloader>=0.1.1->edsnlp==0.9.1->medkit-lib==0.13a0) (2.5)
# Requirement already satisfied: attrs>=17.3.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (1.9.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec->torch<3.0.0,>=2.1.1->medkit-lib==0.13a0) (4.0.3)
# Requirement already satisfied: Mako in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from alembic>=1.5.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (1.3.0)
# Requirement already satisfied: platformdirs>=2.5.0 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from pooch>=1.0->librosa>=0.6.0->torch-audiomentations>=0.11.0->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.11.0)
# Requirement already satisfied: greenlet!=0.4.17 in /home/obirot/dev/medkit/.venv/lib/python3.8/site-packages (from sqlalchemy>=1.3.0->optuna>=3.1->pyannote.pipeline>=3.0.1->pyannote-audio<4.0,>=3.1->medkit-lib==0.13a0) (3.0.1)
# medkit-lib is already installed with the same version as the provided wheel. Use --force-reinstall to force an installation of the wheel.
#
# [notice] A new release of pip is available: 23.2.1 -> 23.3.1
# [notice] To update, run: pip install --upgrade pip

# %%
from medkit.core import DocPipeline, PipelineStep
from medkit.text.segmentation import SentenceTokenizer, SyntagmaTokenizer
from medkit.text.context import FamilyDetector, NegationDetector
from medkit.text.ner import UMLSMatcher, EDSNLPDateMatcher

pipeline = DocPipeline(
    # receive raw text
    input="full_text",
    steps=[
        # split it in sentences
        PipelineStep(
            operation=SentenceTokenizer(),
            input="full_text",
            output="sentences",
        ),
        # detect sentences about family history
        PipelineStep(
            operation=FamilyDetector(),
            input="sentences",
        ),
        # split sentences in syntagmas
        PipelineStep(
            operation=SyntagmaTokenizer(),
            input="sentences",
            output="syntagmas",
        ),
        # detected negated syntagmas
        PipelineStep(
            operation=NegationDetector(),
            input="syntagmas",
        ),
        # find medical entities using the UMLS knowledge base
        PipelineStep(
            operation=UMLSMatcher(umls_dir="umls/", language="FRE"),
            input="syntagmas",
            output="medical_entities",
        ),
        # find dates
        PipelineStep(
            operation=EDSNLPDateMatcher(),
            input="syntagmas",
            output="dates",
        ),
    ],
    # keep medical entities and dates found
    output=["medical_entities", "dates"],
)

# %%
from medkit.core.text import TextDocument

# load medical report and apply pipeline
doc = TextDocument.from_file("report.txt")
pipeline.run([doc])

# %%
from spacy import displacy
from medkit.text.spacy.displacy_utils import medkit_doc_to_displacy

# enrich entity labels with negation [n] or family [f] indicators
def format(entity):
    label = entity.label
    negation_attr = entity.attrs.get(label="negation")[0]
    if negation_attr.value:
        return label + "[n]"
    family_attr = entity.attrs.get(label="family")[0]
    if family_attr.value:
        return label + "[f]"
    return label

# custom colors
COLORS = {"chemical": "#0eab81", "anatomy": "#0eab81", "procedure": "#0eab81", "disorder": "#0eab81", "disorder[n]": "#f5b0b0", "disorder[f]": "#dce9fc",}

# displacy document and entities using displacy
displacy_data = medkit_doc_to_displacy(doc, entity_formatter=format)
displacy.render(docs=displacy_data, manual=True, style="ent", options=dict(colors=COLORS))
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">PLAINTE PRINCIPALE :<br>
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thrombocytose essentielle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
# .<br><br>ANTÉCÉDENTS DE LA
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MALADIE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
#  ACTUELLE : <br>C'est un M. de 64 ans que je suis pour une
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thrombocytose essentielle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
# . Il a été initialement diagnostiqué lorsqu'il a vu un hématologue pour la première fois le
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     09/07/07
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">date</span>
# </mark>
# . A cette époque, son nombre de
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plaquettes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">anatomy</span>
# </mark>
#  était de 1 240 000. Il a d'abord commencé à prendre de l'Hydrea 1000 mg par jour. Le
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     07/11/07
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">date</span>
# </mark>
# , il a subi une
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     biopsie de moelle osseuse
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">procedure</span>
# </mark>
# , qui a montré une
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     thrombocytose essentielle
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
# . Il était positif pour la
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     mutation JAK-2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
# . Le
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     11/06/07
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">date</span>
# </mark>
# , ses
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     plaquettes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">anatomy</span>
# </mark>
#  étaient à 766 000. Sa dose actuelle d'Hydrea est maintenant de 1500 mg les lundis et vendredis et de 1000 mg tous les autres jours. Il a déménagé à ABCD en
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     décembre 2009
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">date</span>
# </mark>
#  pour tenter d'améliorer la
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     polyarthrite rhumatoïde
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder</span>
# </mark>
#  de sa femme. Dans l'ensemble, il se porte bien. Il a un bon niveau d'énergie et son statut de performance
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     ECOG
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">procedure</span>
# </mark>
#  est de 0. Absence de
# <mark class="entity" style="background: #f5b0b0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     fièvre
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder[n]</span>
# </mark>
# ,
# <mark class="entity" style="background: #f5b0b0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     frissons
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder[n]</span>
# </mark>
#  ou
# <mark class="entity" style="background: #f5b0b0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sueurs nocturnes
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder[n]</span>
# </mark>
# . Pas d'
# <mark class="entity" style="background: #f5b0b0; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     adénopathie
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">disorder[n]</span>
# </mark>
# . Pas de nausées ni de vomissements. Aucun changement dans les habitudes intestinales ou vésicales.<br><br>
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     MÉDICAMENTS
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">chemical</span>
# </mark>
#  ACTUELS : <br>Hydrea 1500 mg les lundis et vendredis et 1000 mg les autres jours de la semaine, Mecir 1cp/j,
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vitamine D
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">chemical</span>
# </mark>
#  1/j,
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     aspirine
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">chemical</span>
# </mark>
#  80 mg 1/j et
# <mark class="entity" style="background: #0eab81; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     vitamine C
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">chemical</span>
# </mark>
#  1/j <br><br>ALLERGIES : <br>Aucune
# <mark class="entity" style="background: #f5b0b0; paddi
